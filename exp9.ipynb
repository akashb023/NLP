# %% [markdown]
# <a href="https://colab.research.google.com/github/akashb023/NLP/blob/main/exp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install gensim
# !pip install nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 47.7 MB/s eta 0:00:00
# ...

# %%
import nltk
import urllib
import bs4 as bs
import re
import requests
from bs4 import BeautifulSoup
from gensim.models import Word2Vec

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
url = "https://en.wikipedia.org/wiki/Global_warming"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

source = response.text

print("Page loaded successfully")
# Out:
# Page loaded successfully

# %%
soup = bs.BeautifulSoup(source,'lxml')

text = ""

for paragraph in soup.find_all('p'):
    text += paragraph.text

# %%
text = re.sub(r'\[[0-9]*\]', ' ', text)
text = re.sub(r'\s+', ' ', text)
text = text.lower()
text = re.sub(r'\d', ' ', text)
text = re.sub(r'\s+', ' ', text)

# %%
nltk.download('punkt_tab')
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

print(sentences[:5])
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ...

# %%
model = Word2Vec(sentences, vector_size=100, min_count=1)

# %%
words = model.wv.index_to_key
print(words[:20])
# Out:
# ['.', ',', 'the', 'and', 'of', 'to', 'in', 'climate', 'is', 'a', 'change', 'warming', 'as', 'for', 'that', 'by', 'are', 'global', 'have', 'emissions']

# %%
words = model.wv.index_to_key
print(words[:20])
# Out:
# ['.', ',', 'the', 'and', 'of', 'to', 'in', 'climate', 'is', 'a', 'change', 'warming', 'as', 'for', 'that', 'by', 'are', 'global', 'have', 'emissions']
